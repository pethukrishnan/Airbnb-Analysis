# %%
import pymongo
import pandas as pd
# import dataprep.eda.create_report as report
pd.set_option('display.max_columns', None)

# %%
gopi = pymongo.MongoClient("mongodb+srv://krish:Krish1619$@cluster0.n1ufxcn.mongodb.net/?retryWrites=true&w=majority")
db = gopi['sample_airbnb']
col = db['listingsAndReviews']

# %% [markdown]
# **Primary Table**

# %%
data = []
for i in col.find( {}, {'_id':1,'listing_url':1,'name':1,'property_type':1,'room_type':1,'bed_type':1,
                        'minimum_nights':1,'maximum_nights':1,'cancellation_policy':1,'accommodates':1,
                        'bedrooms':1,'beds':1,'number_of_reviews':1,'bathrooms':1,'price':1,
                        'cleaning_fee':1,'extra_people':1,'guests_included':1,'images.picture_url':1,
                        'review_scores.review_scores_rating':1} ):
    data.append(i)

df_1 = pd.DataFrame(data)
df_1['images'] = df_1['images'].apply(lambda x: x['picture_url'])
df_1['review_scores'] = df_1['review_scores'].apply(lambda x: x.get('review_scores_rating',0))
df_1.head()
# Out:
#         _id                            listing_url  \
# 0   1001265   https://www.airbnb.com/rooms/1001265
# 1  10030955  https://www.airbnb.com/rooms/10030955
# 2  10059244  https://www.airbnb.com/rooms/10059244
# 3  10021707  https://www.airbnb.com/rooms/10021707
# 4  10006546  https://www.airbnb.com/rooms/10006546
#
#                                                name property_type  \
# 0                  Ocean View Waikiki Marina w/prkg   Condominium
# 1                       Apt Linda Vista Lagoa - Rio     Apartment
# 2  Ligne verte - à 15 min de métro du centre ville.     Apartment
# 3                          Private Room in Bushwick     Apartment
# 4                           Ribeira Charming Duplex         House
#
#          room_type  bed_type minimum_nights maximum_nights  \
# 0  Entire home/apt  Real Bed              3            365
# 1     Private room  Real Bed              1           1125
# 2  Entire home/apt  Real Bed              2           1125
# 3     Private room  Real Bed             14           1125
# 4  Entire home/apt  Real Bed              2             30
#
#            cancellation_policy  accommodates  bedrooms  beds  \
# 0  strict_14_with_grace_period             2       1.0   1.0
# 1                     flexible             2       1.0   1.0
# 2                     moderate             2       0.0   1.0
# 3                     flexible             1       1.0   1.0
# 4                     moderate             8       3.0   5.0
#
#    number_of_reviews bathrooms   price cleaning_fee extra_people  \
# 0                 96       1.0  115.00       100.00         0.00
# 1                  0       2.0  701.00       250.00         0.00
# 2                  0       1.0   43.00          NaN        12.00
# 3                  1       1.5   40.00          NaN         0.00
# 4                 51       1.0   80.00        35.00        15.00
#
#   guests_included                                             images  \
# 0               1  https://a0.muscache.com/im/pictures/15037101/5...
# 1               1  https://a0.muscache.com/im/pictures/59c516bd-c...
# 2               1  https://a0.muscache.com/im/pictures/af5c069c-e...
# 3               1  https://a0.muscache.com/im/pictures/72844c8c-f...
# 4               6  https://a0.muscache.com/im/pictures/e83e702f-e...
#
#    review_scores
# 0             84
# 1              0
# 2              0
# 3            100
# 4             89

# %%
report(df_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 report(df_1)
#
# NameError: name 'report' is not defined

# %%
df_1.isnull().sum()
# Out:
# _id                       0
# listing_url               0
# name                      0
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# cleaning_fee           1531
# extra_people              0
# guests_included           0
# images                    0
# review_scores             0
# dtype: int64

# %%
df_1['bedrooms'].fillna(0, inplace=True)
df_1['beds'].fillna(0, inplace=True)
df_1['bathrooms'].fillna(0, inplace=True)
df_1['cleaning_fee'].fillna('Not Specified', inplace=True)
df_1.isnull().sum()
# Out:
# _id                    0
# listing_url            0
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# cleaning_fee           0
# extra_people           0
# guests_included        0
# images                 0
# review_scores          0
# dtype: int64

# %%
df_1.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights          object
# maximum_nights          object
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms               object
# price                   object
# cleaning_fee            object
# extra_people            object
# guests_included         object
# images                  object
# review_scores            int64
# dtype: object

# %%
df_1['minimum_nights'] = df_1['minimum_nights'].astype(int)
df_1['maximum_nights'] = df_1['maximum_nights'].astype(int)
df_1['bedrooms'] = df_1['bedrooms'].astype(int)
df_1['beds'] = df_1['beds'].astype(int)
df_1['bathrooms'] = df_1['bathrooms'].astype(str).astype(float)
df_1['price'] = df_1['price'].astype(str).astype(float).astype(int)
df_1['cleaning_fee'] = df_1['cleaning_fee'].apply(lambda x: int(float(str(x))) if x != 'Not Specified' else 'Not Specified')
df_1['extra_people'] = df_1['extra_people'].astype(str).astype(float).astype(int)
df_1['guests_included'] = df_1['guests_included'].astype(str).astype(int)

# %%
df_1.dtypes
# Out:
# _id                     object
# listing_url             object
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights           int32
# maximum_nights           int32
# cancellation_policy     object
# accommodates             int64
# bedrooms                 int32
# beds                     int32
# number_of_reviews        int64
# bathrooms              float64
# price                    int32
# cleaning_fee            object
# extra_people             int32
# guests_included          int32
# images                  object
# review_scores            int64
# dtype: object

# %%
df_1.describe().T
# Out:
#                     count          mean           std  min   25%     50%  \
# minimum_nights     5555.0  5.564356e+00  2.261386e+01  1.0   1.0     2.0
# maximum_nights     5555.0  1.382776e+06  5.256920e+07  1.0  59.0  1125.0
# accommodates       5555.0  3.505851e+00  2.297019e+00  1.0   2.0     3.0
# bedrooms           5555.0  1.410441e+00  1.042334e+00  0.0   1.0     1.0
# beds               5555.0  2.066607e+00  1.620858e+00  0.0   1.0     2.0
# number_of_reviews  5555.0  2.760648e+01  4.979838e+01  0.0   1.0     5.0
# bathrooms          5555.0  1.288839e+00  7.037643e-01  0.0   1.0     1.0
# price              5555.0  2.787662e+02  8.422155e+02  9.0  70.0   129.0
# extra_people       5555.0  2.279190e+01  6.933151e+01  0.0   0.0     0.0
# guests_included    5555.0  1.747435e+00  1.487352e+00  1.0   1.0     1.0
# review_scores      5555.0  6.839568e+01  4.182983e+01  0.0   0.0    92.0
#
#                       75%           max
# minimum_nights        3.0  1.250000e+03
# maximum_nights     1125.0  2.147484e+09
# accommodates          4.0  1.600000e+01
# bedrooms              2.0  2.000000e+01
# beds                  3.0  2.500000e+01
# number_of_reviews    32.0  5.330000e+02
# bathrooms             1.0  1.600000e+01
# price               280.0  4.884200e+04
# extra_people         20.0  2.346000e+03
# guests_included       2.0  1.600000e+01
# review_scores        98.0  1.000000e+02

# %%
df_1.head(2)
# Out:
#         _id                            listing_url  \
# 0   1001265   https://www.airbnb.com/rooms/1001265
# 1  10030955  https://www.airbnb.com/rooms/10030955
#
#                                name property_type        room_type  bed_type  \
# 0  Ocean View Waikiki Marina w/prkg   Condominium  Entire home/apt  Real Bed
# 1       Apt Linda Vista Lagoa - Rio     Apartment     Private room  Real Bed
#
#    minimum_nights  maximum_nights          cancellation_policy  accommodates  \
# 0               3             365  strict_14_with_grace_period             2
# 1               1            1125                     flexible             2
#
#    bedrooms  beds  number_of_reviews  bathrooms  price cleaning_fee  \
# 0         1     1                 96        1.0    115          100
# 1         1     1                  0        2.0    701          250
#
#    extra_people  guests_included  \
# 0             0                1
# 1             0                1
#
#                                               images  review_scores
# 0  https://a0.muscache.com/im/pictures/15037101/5...             84
# 1  https://a0.muscache.com/im/pictures/59c516bd-c...              0

# %% [markdown]
# **Host**

# %%
host = []
for i in col.find( {}, {'_id':1, 'host':1}):
    host.append(i)

df_host = pd.DataFrame(host)
host_keys = list(df_host.iloc[0,1].keys())
host_keys.remove('host_about')

for i in host_keys:
    if i == 'host_response_time':
        df_host['host_response_time'] = df_host['host'].apply(lambda x: x['host_response_time'] if 'host_response_time' in x else 'Not Specified')
    else:
        df_host[i] = df_host['host'].apply(lambda x: x[i] if i in x and x[i]!='' else 'Not Specified')

df_host.drop(columns=['host'], inplace=True)
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0   1001265   5448114   https://www.airbnb.com/users/show/5448114
# 1  10030955  51496939  https://www.airbnb.com/users/show/51496939
# 2  10059244   7140229   https://www.airbnb.com/users/show/7140229
# 3  10021707  11275734  https://www.airbnb.com/users/show/11275734
# 4  10006546  51399391  https://www.airbnb.com/users/show/51399391
#
#      host_name                      host_location host_response_time  \
# 0        David    Honolulu, Hawaii, United States     within an hour
# 1        Livia                                 BR      Not Specified
# 2         Caro           Montreal, Quebec, Canada     within an hour
# 3         Josh  New York, New York, United States      Not Specified
# 4  Ana&Gonçalo    Porto, Porto District, Portugal     within an hour
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/5448114/profi...
# 1  https://a0.muscache.com/im/pictures/b7911710-9...
# 2  https://a0.muscache.com/im/pictures/user/c6477...
# 3  https://a0.muscache.com/im/users/11275734/prof...
# 4  https://a0.muscache.com/im/pictures/fab79f25-2...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/5448114/profi...            Waikiki
# 1  https://a0.muscache.com/im/pictures/b7911710-9...              Lagoa
# 2  https://a0.muscache.com/im/pictures/user/c6477...      Not Specified
# 3  https://a0.muscache.com/im/users/11275734/prof...           Bushwick
# 4  https://a0.muscache.com/im/pictures/fab79f25-2...      Not Specified
#
#   host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0                 98              False                  True
# 1      Not Specified              False                  True
# 2                100              False                  True
# 3      Not Specified              False                  True
# 4                100              False                  True
#
#    host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                   False                   18                         18
# 1                   False                    1                          1
# 2                   False                    1                          1
# 3                    True                    1                          1
# 4                    True                    3                          3
#
#                                   host_verifications
# 0                       [email, phone, reviews, kba]
# 1               [email, phone, jumio, government_id]
# 2      [email, phone, reviews, jumio, government_id]
# 3                       [email, phone, reviews, kba]
# 4  [email, phone, reviews, jumio, offline_governm...

# %%
df_host['host_is_superhost'] = df_host['host_is_superhost'].map({False:'No',True:'Yes'})
df_host['host_has_profile_pic'] = df_host['host_has_profile_pic'].map({False:'No',True:'Yes'})
df_host['host_identity_verified'] = df_host['host_identity_verified'].map({False:'No',True:'Yes'})
df_host.head()
# Out:
#         _id   host_id                                    host_url  \
# 0   1001265   5448114   https://www.airbnb.com/users/show/5448114
# 1  10030955  51496939  https://www.airbnb.com/users/show/51496939
# 2  10059244   7140229   https://www.airbnb.com/users/show/7140229
# 3  10021707  11275734  https://www.airbnb.com/users/show/11275734
# 4  10006546  51399391  https://www.airbnb.com/users/show/51399391
#
#      host_name                      host_location host_response_time  \
# 0        David    Honolulu, Hawaii, United States     within an hour
# 1        Livia                                 BR      Not Specified
# 2         Caro           Montreal, Quebec, Canada     within an hour
# 3         Josh  New York, New York, United States      Not Specified
# 4  Ana&Gonçalo    Porto, Porto District, Portugal     within an hour
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/5448114/profi...
# 1  https://a0.muscache.com/im/pictures/b7911710-9...
# 2  https://a0.muscache.com/im/pictures/user/c6477...
# 3  https://a0.muscache.com/im/users/11275734/prof...
# 4  https://a0.muscache.com/im/pictures/fab79f25-2...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/5448114/profi...            Waikiki
# 1  https://a0.muscache.com/im/pictures/b7911710-9...              Lagoa
# 2  https://a0.muscache.com/im/pictures/user/c6477...      Not Specified
# 3  https://a0.muscache.com/im/users/11275734/prof...           Bushwick
# 4  https://a0.muscache.com/im/pictures/fab79f25-2...      Not Specified
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                 98                No                  Yes
# 1      Not Specified                No                  Yes
# 2                100                No                  Yes
# 3      Not Specified                No                  Yes
# 4                100                No                  Yes
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                     No                   18                         18
# 1                     No                    1                          1
# 2                     No                    1                          1
# 3                    Yes                    1                          1
# 4                    Yes                    3                          3
#
#                                   host_verifications
# 0                       [email, phone, reviews, kba]
# 1               [email, phone, jumio, government_id]
# 2      [email, phone, reviews, jumio, government_id]
# 3                       [email, phone, reviews, kba]
# 4  [email, phone, reviews, jumio, offline_governm...

# %%
df_host.isnull().sum()
# Out:
# _id                          0
# host_id                      0
# host_url                     0
# host_name                    0
# host_location                0
# host_response_time           0
# host_thumbnail_url           0
# host_picture_url             0
# host_neighbourhood           0
# host_response_rate           0
# host_is_superhost            0
# host_has_profile_pic         0
# host_identity_verified       0
# host_listings_count          0
# host_total_listings_count    0
# host_verifications           0
# dtype: int64

# %%
df_host.dtypes
# Out:
# _id                          object
# host_id                      object
# host_url                     object
# host_name                    object
# host_location                object
# host_response_time           object
# host_thumbnail_url           object
# host_picture_url             object
# host_neighbourhood           object
# host_response_rate           object
# host_is_superhost            object
# host_has_profile_pic         object
# host_identity_verified       object
# host_listings_count           int64
# host_total_listings_count     int64
# host_verifications           object
# dtype: object

# %% [markdown]
# **Address**

# %%
address = []
for i in col.find( {}, {'_id':1, 'address':1}):
    address.append(i)

df_address = pd.DataFrame(address)
address_keys = list(df_address.iloc[0,1].keys())

for i in address_keys:
    if i == 'location':
        df_address['location_type'] = df_address['address'].apply(lambda x: x['location']['type'])
        df_address['longitude'] = df_address['address'].apply(lambda x: x['location']['coordinates'][0])
        df_address['latitude'] = df_address['address'].apply(lambda x: x['location']['coordinates'][1])
        df_address['is_location_exact'] = df_address['address'].apply(lambda x: x['location']['is_location_exact'])
    else:
        df_address[i] = df_address['address'].apply(lambda x: x[i] if x[i]!='' else 'Not Specified')

df_address.drop(columns=['address'], inplace=True)
df_address.head()
# Out:
#         _id                                  street                 suburb  \
# 0   1001265             Honolulu, HI, United States                  Oʻahu
# 1  10030955  Rio de Janeiro, Rio de Janeiro, Brazil                  Lagoa
# 2  10059244                Montréal, Québec, Canada  Hochelaga-Maisonneuve
# 3  10021707             Brooklyn, NY, United States               Brooklyn
# 4  10006546                  Porto, Porto, Portugal          Not Specified
#
#                                      government_area          market  \
# 0                               Primary Urban Center            Oahu
# 1                                              Lagoa  Rio De Janeiro
# 2                      Mercier-Hochelaga-Maisonneuve        Montreal
# 3                                           Bushwick        New York
# 4  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
#
#          country country_code location_type   longitude   latitude  \
# 0  United States           US         Point -157.839190  21.286340
# 1         Brazil           BR         Point  -43.205047 -22.971951
# 2         Canada           CA         Point  -73.549490  45.545480
# 3  United States           US         Point  -73.936150  40.697910
# 4       Portugal           PT         Point   -8.613080  41.141300
#
#    is_location_exact
# 0               True
# 1               True
# 2              False
# 3               True
# 4              False

# %%
df_address['is_location_exact'] = df_address['is_location_exact'].map({False:'No',True:'Yes'})
df_address.head()
# Out:
#         _id                                  street                 suburb  \
# 0   1001265             Honolulu, HI, United States                  Oʻahu
# 1  10030955  Rio de Janeiro, Rio de Janeiro, Brazil                  Lagoa
# 2  10059244                Montréal, Québec, Canada  Hochelaga-Maisonneuve
# 3  10021707             Brooklyn, NY, United States               Brooklyn
# 4  10006546                  Porto, Porto, Portugal          Not Specified
#
#                                      government_area          market  \
# 0                               Primary Urban Center            Oahu
# 1                                              Lagoa  Rio De Janeiro
# 2                      Mercier-Hochelaga-Maisonneuve        Montreal
# 3                                           Bushwick        New York
# 4  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
#
#          country country_code location_type   longitude   latitude  \
# 0  United States           US         Point -157.839190  21.286340
# 1         Brazil           BR         Point  -43.205047 -22.971951
# 2         Canada           CA         Point  -73.549490  45.545480
# 3  United States           US         Point  -73.936150  40.697910
# 4       Portugal           PT         Point   -8.613080  41.141300
#
#   is_location_exact
# 0               Yes
# 1               Yes
# 2                No
# 3               Yes
# 4                No

# %%
df_address.isnull().sum()
# Out:
# _id                  0
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# location_type        0
# longitude            0
# latitude             0
# is_location_exact    0
# dtype: int64

# %%
df_address.dtypes
# Out:
# _id                   object
# street                object
# suburb                object
# government_area       object
# market                object
# country               object
# country_code          object
# location_type         object
# longitude            float64
# latitude             float64
# is_location_exact     object
# dtype: object

# %% [markdown]
# **Availability**

# %%
availability = []
for i in col.find( {}, {'_id':1, 'availability':1}):
    availability.append(i)

df_availability = pd.DataFrame(availability)
availability_keys = list(df_availability.iloc[0,1].keys())

for i in availability_keys:
    df_availability['availability_30'] = df_availability['availability'].apply(lambda x: x['availability_30'])
    df_availability['availability_60'] = df_availability['availability'].apply(lambda x: x['availability_60'])
    df_availability['availability_90'] = df_availability['availability'].apply(lambda x: x['availability_90'])
    df_availability['availability_365'] = df_availability['availability'].apply(lambda x: x['availability_365'])

df_availability.drop(columns=['availability'], inplace=True)
df_availability.head()
# Out:
#         _id  availability_30  availability_60  availability_90  \
# 0   1001265               16               46               76
# 1  10030955               28               58               88
# 2  10059244                0                0                0
# 3  10021707                0                0                0
# 4  10006546               28               47               74
#
#    availability_365
# 0               343
# 1               363
# 2                32
# 3                 0
# 4               239

# %%
df_availability.isnull().sum()
# Out:
# _id                 0
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
df_availability.dtypes
# Out:
# _id                 object
# availability_30      int64
# availability_60      int64
# availability_90      int64
# availability_365     int64
# dtype: object

# %% [markdown]
# **Amenities**

# %%
def amenities_sort(x):
    a = x
    a.sort(reverse=False)
    return a

amenities = []
for i in col.find( {}, {'_id':1, 'amenities':1}):
    amenities.append(i)

df_amenities = pd.DataFrame(amenities)
df_amenities['amenities'] = df_amenities['amenities'].apply(lambda x: amenities_sort(x))
df_amenities.head()
# Out:
#         _id                                          amenities
# 0   1001265  [Air conditioning, BBQ grill, Bed linens, Cabl...
# 1  10030955  [24-hour check-in, Air conditioning, Buzzer/wi...
# 2  10059244  [Bed linens, Essentials, Free parking on premi...
# 3  10021707  [Air conditioning, Buzzer/wireless intercom, C...
# 4  10006546  [Bed linens, Buzzer/wireless intercom, Cable T...

# %%
df_amenities.isnull().sum()
# Out:
# _id          0
# amenities    0
# dtype: int64

# %%
df_amenities.dtypes
# Out:
# _id          object
# amenities    object
# dtype: object

# %%
df = pd.merge(df_1, df_host, on='_id')
df = pd.merge(df, df_address, on='_id')
df = pd.merge(df, df_availability, on='_id')
df = pd.merge(df, df_amenities, on='_id')
df.head(3)
# Out:
#         _id                            listing_url  \
# 0   1001265   https://www.airbnb.com/rooms/1001265
# 1  10030955  https://www.airbnb.com/rooms/10030955
# 2  10059244  https://www.airbnb.com/rooms/10059244
#
#                                                name property_type  \
# 0                  Ocean View Waikiki Marina w/prkg   Condominium
# 1                       Apt Linda Vista Lagoa - Rio     Apartment
# 2  Ligne verte - à 15 min de métro du centre ville.     Apartment
#
#          room_type  bed_type  minimum_nights  maximum_nights  \
# 0  Entire home/apt  Real Bed               3             365
# 1     Private room  Real Bed               1            1125
# 2  Entire home/apt  Real Bed               2            1125
#
#            cancellation_policy  accommodates  bedrooms  beds  \
# 0  strict_14_with_grace_period             2         1     1
# 1                     flexible             2         1     1
# 2                     moderate             2         0     1
#
#    number_of_reviews  bathrooms  price   cleaning_fee  extra_people  \
# 0                 96        1.0    115            100             0
# 1                  0        2.0    701            250             0
# 2                  0        1.0     43  Not Specified            12
#
#    guests_included                                             images  \
# 0                1  https://a0.muscache.com/im/pictures/15037101/5...
# 1                1  https://a0.muscache.com/im/pictures/59c516bd-c...
# 2                1  https://a0.muscache.com/im/pictures/af5c069c-e...
#
#    review_scores   host_id                                    host_url  \
# 0             84   5448114   https://www.airbnb.com/users/show/5448114
# 1              0  51496939  https://www.airbnb.com/users/show/51496939
# 2              0   7140229   https://www.airbnb.com/users/show/7140229
#
#   host_name                    host_location host_response_time  \
# 0     David  Honolulu, Hawaii, United States     within an hour
# 1     Livia                               BR      Not Specified
# 2      Caro         Montreal, Quebec, Canada     within an hour
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/5448114/profi...
# 1  https://a0.muscache.com/im/pictures/b7911710-9...
# 2  https://a0.muscache.com/im/pictures/user/c6477...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/5448114/profi...            Waikiki
# 1  https://a0.muscache.com/im/pictures/b7911710-9...              Lagoa
# 2  https://a0.muscache.com/im/pictures/user/c6477...      Not Specified
#
#   host_response_rate host_is_superhost host_has_profile_pic  \
# 0                 98                No                  Yes
# 1      Not Specified                No                  Yes
# 2                100                No                  Yes
#
#   host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                     No                   18                         18
# 1                     No                    1                          1
# 2                     No                    1                          1
#
#                               host_verifications  \
# 0                   [email, phone, reviews, kba]
# 1           [email, phone, jumio, government_id]
# 2  [email, phone, reviews, jumio, government_id]
#
#                                    street                 suburb  \
# 0             Honolulu, HI, United States                  Oʻahu
# 1  Rio de Janeiro, Rio de Janeiro, Brazil                  Lagoa
# 2                Montréal, Québec, Canada  Hochelaga-Maisonneuve
#
#                  government_area          market        country country_code  \
# 0           Primary Urban Center            Oahu  United States           US
# 1                          Lagoa  Rio De Janeiro         Brazil           BR
# 2  Mercier-Hochelaga-Maisonneuve        Montreal         Canada           CA
#
#   location_type   longitude   latitude is_location_exact  availability_30  \
# 0         Point -157.839190  21.286340               Yes               16
# 1         Point  -43.205047 -22.971951               Yes               28
# 2         Point  -73.549490  45.545480                No                0
#
#    availability_60  availability_90  availability_365  \
# 0               46               76               343
# 1               58               88               363
# 2                0                0                32
#
#                                            amenities
# 0  [Air conditioning, BBQ grill, Bed linens, Cabl...
# 1  [24-hour check-in, Air conditioning, Buzzer/wi...
# 2  [Bed linens, Essentials, Free parking on premi...

# %%
# download as csv
df.to_csv('airbnb.csv', index=False)

# %%
df.dtypes
# Out:
# _id                           object
# listing_url                   object
# name                          object
# property_type                 object
# room_type                     object
# bed_type                      object
# minimum_nights                 int32
# maximum_nights                 int32
# cancellation_policy           object
# accommodates                   int64
# bedrooms                       int32
# beds                           int32
# number_of_reviews              int64
# bathrooms                    float64
# price                          int32
# cleaning_fee                  object
# extra_people                   int32
# guests_included                int32
# images                        object
# review_scores                  int64
# host_id                       object
# host_url                      object
# host_name                     object
# host_location                 object
# host_response_time            object
# host_thumbnail_url            object
# host_picture_url              object
# host_neighbourhood            object
# host_response_rate            object
# host_is_superhost             object
# host_has_profile_pic          object
# host_identity_verified        object
# host_listings_count            int64
# host_total_listings_count      int64
# host_verifications            object
# street                        object
# suburb                        object
# government_area               object
# market                        object
# country                       object
# country_code                  object
# location_type                 object
# longitude                    float64
# latitude                     float64
# is_location_exact             object
# availability_30                int64
# availability_60                int64
# availability_90                int64
# availability_365               int64
# amenities                     object
# dtype: object
